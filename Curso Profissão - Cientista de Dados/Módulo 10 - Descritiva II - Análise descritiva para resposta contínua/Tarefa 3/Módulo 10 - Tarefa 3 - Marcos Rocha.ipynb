# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Profissao- Cientista de Dados_M10_support material.csv')

df = df.drop(columns='Unnamed: 0')
df.drop_duplicates(inplace=True)

df
# Out:
#          data_ref  index sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0      2015-01-01   8682    F             False             True           1
# 1      2015-01-01  12830    M              True             True           0
# 2      2015-01-01   2885    M              True             True           2
# 3      2015-01-01  16168    F              True            False           0
# 4      2015-01-01  12438    M             False            False           0
# ...           ...    ...  ...               ...              ...         ...
# 14994  2016-03-01  16065    M              True             True           0
# 14995  2016-03-01   3678    M              True             True           1
# 14996  2016-03-01   3405    M              True             True           1
# 14998  2016-03-01  16019    F             False             True           0
# 14999  2016-03-01  12895    F              True             True           0
#
# ...

# %%
df['data_ref'] = pd.to_datetime(arg=df['data_ref'])
df['data_ref'] = df['data_ref'].map(lambda x: x.strftime('%b/%Y'))

# %%
df.select_dtypes(include=['object', 'bool']).columns
# Out:
# Index(['data_ref', 'sexo', 'posse_de_veiculo', 'posse_de_imovel', 'tipo_renda',
#        'educacao', 'estado_civil', 'tipo_residencia', 'mau'],
#       dtype='object')

# %%
df
# Out:
#        data_ref  index sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0      Jan/2015   8682    F             False             True           1
# 1      Jan/2015  12830    M              True             True           0
# 2      Jan/2015   2885    M              True             True           2
# 3      Jan/2015  16168    F              True            False           0
# 4      Jan/2015  12438    M             False            False           0
# ...         ...    ...  ...               ...              ...         ...
# 14994  Mar/2016  16065    M              True             True           0
# 14995  Mar/2016   3678    M              True             True           1
# 14996  Mar/2016   3405    M              True             True           1
# 14998  Mar/2016  16019    F             False             True           0
# 14999  Mar/2016  12895    F              True             True           0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14547 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_ref               14547 non-null  object
#  1   index                  14547 non-null  int64
#  2   sexo                   14547 non-null  object
#  3   posse_de_veiculo       14547 non-null  bool
#  4   posse_de_imovel        14547 non-null  bool
#  5   qtd_filhos             14547 non-null  int64
#  6   tipo_renda             14547 non-null  object
#  7   educacao               14547 non-null  object
#  8   estado_civil           14547 non-null  object
#  9   tipo_residencia        14547 non-null  object
#  10  idade                  14547 non-null  int64
#  11  tempo_emprego          12087 non-null  float64
#  12  qt_pessoas_residencia  14547 non-null  float64
#  13  mau                    14547 non-null  bool
# ...

# %%
plt.rc('figure', figsize=(12,6))
sns.countplot(x='data_ref', hue='sexo', data=df)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %%
sns.countplot(x='data_ref', hue='tipo_residencia', data=df)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %%
sns.countplot(x='data_ref', hue='tipo_renda', data=df)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %%
sns.countplot(x='data_ref', hue='educacao', data=df)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %%
sns.countplot(x='data_ref', hue='estado_civil', data=df)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %% [markdown]
# Ao longo do tempo, a partir de setembro de 2015, houve um aumento significativo de dados com a escolaridade de ensino superior completo, o que resultou em uma queda na quantidade de dados com a escolaridade secundária. A distribuição manteve a mesma proporção até o final do período analisado após essa alteração, e seria importante investigar essa mudança.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
sns.pointplot(x='data_ref', y='renda', hue='sexo', data=df, dodge=True, ci=95)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')

plt.show()

sns.pointplot(x='data_ref', y='renda', hue='tipo_residencia', data=df, dodge=True, ci=95)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')

plt.show()

sns.pointplot(x='data_ref', y='renda', hue='tipo_renda', data=df, dodge=True, ci=95)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')

plt.show()

sns.pointplot(x='data_ref', y='renda', hue='educacao', data=df, dodge=True, ci=95)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')

plt.show()

sns.pointplot(x='data_ref', y='renda', hue='estado_civil', data=df, dodge=True, ci=95)
plt.xticks(rotation=45)
plt.xlabel(xlabel='Tempo')

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\1035725152.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(x='data_ref', y='renda', hue='sexo', data=df, dodge=True, ci=95)
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\1035725152.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(x='data_ref', y='renda', hue='tipo_residencia', data=df, dodge=True, ci=95)
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\1035725152.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(x='data_ref', y='renda', hue='tipo_renda', data=df, dodge=True, ci=95)
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\1035725152.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
# ...

# %% [markdown]
# Houve uma alteração na variável "educacao", o que resultou em uma diferença em praticamente metade do período analisado. Exceto por esta variável mencionada, acredito que todas as outras variáveis qualitativas possam ser utilizadas em um modelo devido à estabilidade de distribuição ao longo do tempo.
