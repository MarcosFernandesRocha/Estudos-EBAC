# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

# %%
#Salvando a função de verificação de um url e salvando em uma variável: 
r = requests.get(url)

# %%
#Verificando se a url está em status preparado para se trabalhar (200 = ok):
r.status_code
# Out:
# 200

# %%
#Usando a função json para transmitir dados para o python:
data_json = r.json()

# %%
#Imprimindo a lista de dicionários criada para verificação:
print(data_json['items'])
# Out:
# [{'id_pleito': 9750, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001046/2006-92', 'data_protocolo': '2006-07-07T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 305737280, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '13/07/2006'}, {'id_pleito': 10002, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001097/2009-67', 'data_protocolo': '2009-09-09T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Profisco', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 19759050, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '28/09/2009'}, {'id_pleito': 7080, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000492/2012-28', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 300000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '03/09/2012'}, {'id_pleito': 8556, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000797/2010-78', 'data_protocolo': '2011-06-30T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 112000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '04/07/2011'}, {'id_pleito': 11306, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001408/2009-98', 'data_protocolo': '2009-11-23T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Fortalecimento Institucional', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 485000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '25/11/2009'}, {'id_pleito': 10673, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001256/2010-67', 'data_protocolo': '2011-06-03T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'PAC - Copa Estádios', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 400000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '04/07/2011'}, {'id_pleito': 21388, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': '00000.000000/2024-66', 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000158/2016-06', 'data_protocolo': '2016-02-19T02:00:00Z', 'tipo_operacao': 'Operação cont ...

# %%
#Criando um DataFrame a partir da extração dos dados:
dados_rio = pd.DataFrame(data_json['items'])
dados_rio.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       9750           Estado  Rio de Janeiro        33  RJ    None
# 1      10002           Estado  Rio de Janeiro        33  RJ    None
# 2       7080           Estado  Rio de Janeiro        33  RJ    None
# 3       8556           Estado  Rio de Janeiro        33  RJ    None
# 4      11306           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0                                           Deferido  17944.001046/2006-92
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001097/2009-67
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000492/2012-28
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001408/2009-98
#
#          data_protocolo                                      tipo_operacao  \
# 0  2006-07-07T03:00:00Z                        Operação contratual interna
# 1  2009-09-09T03:00:00Z  Operação contratual externa (com garantia da U...
# 2  2012-04-16T03:00:00Z  Operação contratual externa (com garantia da U...
# 3  2011-06-30T03:00:00Z  Operação contratual externa (com garantia da U...
# 4  2009-11-23T02:00:00Z  Operação contratual externa (com garantia da U...
#
#                      finalidade                           tipo_credor  \
# 0                Infraestrutura       Instituição Financeira Nacional
# 1                      Profisco  Instituição Financeira Internacional
# 2                Multissetorial  Instituição Financeira Internacional
# 3                Multissetorial  Instituição Financeira Internacional
# 4  Fortalecimento Institucional  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  305737280.0                 1                      0  13/07/2006
# 1   19759050.0                 1                      0  28/09/2009
# 2  300000000.0                 1                      0  03/09/2012
# 3  112000000.0                 1                      0  04/07/2011
# 4  485000000.0                 1                      0  25/11/2009

# %%
#verificação das linhas e colunas do Dataframe:
dados_rio.shape
# Out:
# (52, 18)

# %%
#Checando o conteúdo das colunas do DataFrame:
dados_rio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
#  14  valor                  52 non-null     float64
#  15  pvl_assoc_divida       52 non-null     int64
#  16  pvl_contradado_credor  52 non-null     int64
#  17  data_status            52 non-null     object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 7.4+ KB

# %%
#Verificando o conteúdo da colúna status:
dados_rio['status'].unique()
# Out:
# array(['Deferido',
#        'Encaminhado à PGFN com manifestação técnica favorável',
#        'Arquivado a pedido', 'Arquivado por decurso de prazo'],
#       dtype=object)

# %%
# 2) Os status mais frequêntes encontrados: 
#Encaminhado à PGFN com manifestação técnica favorável 34
#Deferido 14
#Arquivado a pedido 3
dados_rio['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
# 3) Construa uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame. Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().
# Transformando a coluna data_status para o tipo datetime
dados_rio['data_status'] = pd.to_datetime(dados_rio['data_status'])

# Extraindo o ano
dados_rio['ano_status'] = dados_rio['data_status'].dt.year

# Verificando o resultado
print(dados_rio[['data_status', 'ano_status']].head())

display(dados_rio)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 3) Construa uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame. Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().
#       2 # Transformando a coluna data_status para o tipo datetime
# ----> 3 dados_rio['data_status'] = pd.to_datetime(dados_rio['data_status'])
#       5 # Extraindo o ano
#       6 dados_rio['ano_status'] = dados_rio['data_status'].dt.year
#
# NameError: name 'pd' is not defined

# %%
# 3) Jeito alternativo
dados_rio[['dia','mes','ano_status']] = (dados_rio['data_status'].str.split("/",
                                                                    expand = True))
dados_rio.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       9750           Estado  Rio de Janeiro        33  RJ    None
# 1      10002           Estado  Rio de Janeiro        33  RJ    None
# 2       7080           Estado  Rio de Janeiro        33  RJ    None
# 3       8556           Estado  Rio de Janeiro        33  RJ    None
# 4      11306           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0                                           Deferido  17944.001046/2006-92
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001097/2009-67
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000492/2012-28
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001408/2009-98
#
#          data_protocolo                                      tipo_operacao  \
# 0  2006-07-07T03:00:00Z                        Operação contratual interna
# 1  2009-09-09T03:00:00Z  Operação contratual externa (com garantia da U...
# 2  2012-04-16T03:00:00Z  Operação contratual externa (com garantia da U...
# 3  2011-06-30T03:00:00Z  Operação contratual externa (com garantia da U...
# 4  2009-11-23T02:00:00Z  Operação contratual externa (com garantia da U...
#
#    ...                           tipo_credor  \
# 0  ...       Instituição Financeira Nacional
# 1  ...  Instituição Financeira Internacional
# 2  ...  Instituição Financeira Internacional
# 3  ...  Instituição Financeira Internacional
# 4  ...  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#          valor  pvl_assoc_divida  pvl_contradado_credor  data_status dia mes  \
# 0  305737280.0                 1                      0   13/07/2006  13  07
# 1   19759050.0                 1                      0   28/09/2009  28  09
# 2  300000000.0                 1                      0   03/09/2012  03  09
# 3  112000000.0                 1                      0   04/07/2011  04  07
# 4  485000000.0                 1                      0   25/11/2009  25  11
#
#   ano_status
# 0       2006
# 1       2009
# 2       2012
# 3       2011
# 4       2009
#
# [5 rows x 21 columns]

# %%
#4) verificando a frequência de solicitações por ano:
dados_rio['ano_status'].value_counts()
# Out:
# ano_status
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2016     4
# 2002     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) função para extrair os dados a partir do argumento 'UF' e 'Estado' ou 'Município':
def consultar_dados_por_uf(uf, tipo_interessado):
    base_url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
    params = {
        'uf': uf,
        'tipo_interessado': tipo_interessado
    }
    r = requests.get(base_url, params=params)
    if r.status_code == 200:
        data_json = r.json()
        return pd.DataFrame(data_json['items'])
    else:
        print(f'Erro ao consultar API: {r.status_code}')
        return None

# %%
#consultando funcionamento da função (estado):
dados_rj_estado = consultar_dados_por_uf('RO', 'Estado')
dados_rj_estado
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0        5360           Estado    Rondônia        11  RO
# 1       26360           Estado    Rondônia        11  RO
# 2        6974           Estado    Rondônia        11  RO
# 3        9375           Estado    Rondônia        11  RO
# 4       11332           Estado    Rondônia        11  RO
# 5       10630           Estado    Rondônia        11  RO
# 6        6672           Estado    Rondônia        11  RO
# 7        6696           Estado    Rondônia        11  RO
# 8       10538           Estado    Rondônia        11  RO
# 9        4923           Estado    Rondônia        11  RO
# 10      12436           Estado    Rondônia        11  RO
#
#                  num_pvl                                             status  \
# 0                   None                                           Deferido
# 1   PVL02.002127/2017-08                        Deferido (decisão judicial)
# 2                   None                                           Deferido
# 3                   None                                           Deferido
# 4                   None  Encaminhado à PGFN com manifestação técnica fa...
# 5                   None  Encaminhado à PGFN com manifestação técnica fa...
# 6                   None  Encaminhado à PGFN com manifestação técnica fa...
# 7                   None                                           Deferido
# 8                   None                                           Deferido
# 9                   None  Encaminhado à PGFN com manifestação técnica fa...
# 10                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#             num_processo        data_protocolo  \
# 0   17944.000095/2010-94  2010-02-11T02:00:00Z
# 1   17944.101943/2017-58  2018-04-30T14:18:18Z
# 2   17944.000471/2002-31  2002-05-01T03:00:00Z
# 3   17944.000967/2012-86  2012-08-23T03:00:00Z
# 4   17944.001413/2012-04  2012-12-05T02:00:00Z
# 5   17944.001247/2009-32  2011-09-12T03:00:00Z
# 6   17944.000406/2010-15  2011-09-12T03:00:00Z
# 7   17944.000410/2008-69  2008-09-22T03:00:00Z
# 8   17944.001224/2011-42  2012-03-29T03:00:00Z
# 9   10951.000184/2002-92  2002-04-11T03:00:00Z
# 10  17944.001685/2009-09  2010-02-25T03:00:00Z
#
#                                         tipo_operacao  \
# 0                         Operação contratual interna
# 1                         Operação contratual interna
# 2                         Operação contratual interna
# 3                         Operação contratual interna
# 4   Operação contratual interna (com garantia da U...
# 5   Operação contratual externa (com garantia da U...
# 6   Operação contratual interna (com garantia da U...
# 7                         Operação contratual interna
# 8                         Operação contratual interna
# 9   Operação contratual externa (com garantia da U...
# 10  Operação contratual interna (com garantia da U...
#
#                                            finalidade  \
# 0                            Caminho da Escola 2009 A
# 1                             Renegociação de dívidas
# 2                                      Infraestrutura
# 3   PIDISE - Prog. Integ. de Desenv. e Inclusão Só...
# 4                                          Proinveste
# 5                                            Profisco
# 6   PEF - Programa Emergencial de Financiamento do...
# 7                             PAC - Saneamento - 2008
# 8                                  PAC 2 - Saneamento
# 9                                   Saneamento básico
# 10  PEF - Programa Emergencial de Financiamento do...
#
#                              tipo_credor  \
# 0        Instituição Financeira Nacional
# 1                                  União
# 2        Instituição Financeira Nacional
# 3        Instituição Financeira Nacional
# 4        Instituição Financeira Nacional
# 5   Instituição Financeira Internacional
# 6        Instituição Financeira Nacional
# 7        Instituição Financeira Nacional
# 8        Instituição Financeira Nacional
# 9   Instituição Financeira Internacional
# 10       Instituição Financeira Nacional
#
#                                                credor          moeda  \
# 0                                 Banco do Brasil S/A           Real
# 1                                               União           Real
# 2   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4                                 Banco do Brasil S/A           Real
# 5             Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 6   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 7                             Caixa Econômica Federal           Real
# 8                             Caixa Econômica Federal           Real
# 9   Fundo Financeiro para o Desenvolvimento da Bac...  Dólar dos EUA
# 10                                Banco do Brasil S/A           Real
#
#            valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   4.060000e+07                 0                      0  12/02/2009
# 1   2.106685e+09                 0                      0  23/05/2018
# 2   1.362654e+07                 1                      0  20/06/2002
# 3   4.508434e+08                 1                      0  02/10/2012
# 4   4.389211e+08                 1                      0  03/01/2013
# 5   6.231000e+06                 1                      0  04/10/2011
# 6   1.689360e+08                 1                      0  04/10/2011
# 7   1.113766e+08                 1                      0  25/09/2008
# 8   3.187239e+07                 1                      0  20/04/2012
# 9   8.470000e+07                 1                      0  06/06/2002
# 10  1.126240e+08                 1                      0  02/03/2010

# %%
#consultando funcionamento da função (Município):
dados_rj_municipio = consultar_dados_por_uf('RO', 'Município')
dados_rj_municipio
# Out:
#      id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 0        69006        Município                  Vilhena   1100304  RO
# 1        10397        Município              Porto Velho   1100205  RO
# 2        10256        Município      Machadinho do Oeste   1100130  RO
# 3         9860        Município        Colorado do Oeste   1100064  RO
# 4         6215        Município           Rolim de Moura   1100288  RO
# ..         ...              ...                      ...       ...  ..
# 154      66069        Município                    Urupá   1101708  RO
# 155      10110        Município             Castanheiras   1100908  RO
# 156      11811        Município            Pimenta Bueno   1100189  RO
# 157      10605        Município               Rio Crespo   1100262  RO
# 158      10609        Município  Novo Horizonte do Oeste   1100502  RO
#
#                   num_pvl                          status  \
# 0    PVL02.001010/2024-28                      Em análise
# 1                    None                        Deferido
# 2                    None                        Deferido
# 3                    None                    Regularizado
# 4                    None                        Deferido
# ..                    ...                             ...
# 154  PVL02.003041/2023-32               Deferido (PVL-IF)
# 155                  None  Arquivado por decurso de prazo
# 156                  None                    Regularizado
# 157                  None                       Arquivado
# 158                  None                       Arquivado
#
#              num_processo        data_protocolo                tipo_operacao  \
# 0    17944.003884/2024-82  2024-06-28T17:35:54Z  Operação contratual interna
# 1    17944.001190/2011-96  2011-11-30T02:00:00Z  Operação contratual interna
# 2    17944.001155/2014-10  2014-12-29T02:00:00Z  Operação contratual interna
# 3    17944.001067/2011-75  2011-11-01T02:00:00Z  Operação contratual interna
# 4    17944.000300/2007-16  2007-04-19T03:00:00Z  Operação contratual interna
# ..                    ...                   ...                          ...
# 154                  None                  None  Operação contratual interna
# 155  17944.001122/2012-16  2012-11-09T02:00:00Z  Operação contratual interna
# 156  17944.001531/2014-76  2019-08-23T15:43:09Z  Operação contratual interna
# 157  17944.001240/2008-30  2008-05-09T03:00:00Z  Operação contratual interna
# 158  17944.001241/2008-84  2008-07-03T03:00:00Z  Operação contratual interna
#
#                                             finalidade  \
# 0                                       Infraestrutura
# 1    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 2    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 3                     Regularização de Dívida - Outros
# 4                              Renegociação de dívidas
# ..                                                 ...
# 154                                     Infraestrutura
# 155                                  Caminho da Escola
# 156         Regularização de Dívida - Energia Elétrica
# 157                                Caminho da Escola 3
# 158                                Caminho da Escola 3
#
#                          tipo_credor                              credor  \
# 0    Instituição Financeira Nacional                 Banco do Brasil S/A
# 1    Instituição Financeira Nacional             Caixa Econômica Federal
# 2    Instituição Financeira Nacional             Caixa Econômica Federal
# 3                    Empresa Estatal  Centrais Elétricas de Rondônia S/A
# 4                    Empresa Estatal  Centrais Elétricas de Rondônia S/A
# ..                               ...                                 ...
# 154  Instituição Financeira Nacional                 Banco do Brasil S/A
# 155  Instituição Financeira Nacional             Caixa Econômica Federal
# 156                  Empresa Estatal  Centrais Elétricas de Rondônia S/A
# 157  Instituição Financeira Nacional                 Banco do Brasil S/A
# 158  Instituição Financeira Nacional               Banco da Amazônia S/A
#
#     moeda        valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    Real  25000000.00                 0                      0  11/07/2024
# 1    Real  13890000.00                 1                      0  22/12/2011
# 2    Real   7324802.31                 1                      0  05/01/2015
# 3    Real    256411.19                 0                      0  20/01/2012
# 4    Real   2801222.61                 0                      0  23/05/2007
# ..    ...          ...               ...                    ...         ...
# 154  Real   5000000.00                 0                      1  05/09/2023
# 155  Real    735680.00                 0                      0  14/02/2013
# 156  Real   5851519.38                 1                      0  27/08/2019
# 157  Real    299450.00                 0                      0  27/08/2008
# 158  Real    552950.00                 0                      0  02/10/2008
#
# [159 rows x 18 columns]

# %%
# 2) Seu código aqui
#Teste com as seleções para o UF de Minas Gerais:
teste_dados_estado_MG = consultar_dados_por_uf('MG','Estado')
teste_dados_estado_MG.head(10)
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      13587           Estado  Minas Gerais        31  MG
# 1      20458           Estado  Minas Gerais        31  MG
# 2      13672           Estado  Minas Gerais        31  MG
# 3      13695           Estado  Minas Gerais        31  MG
# 4       9197           Estado  Minas Gerais        31  MG
# 5      68204           Estado  Minas Gerais        31  MG
# 6      22380           Estado  Minas Gerais        31  MG
# 7      13447           Estado  Minas Gerais        31  MG
# 8      13595           Estado  Minas Gerais        31  MG
# 9       5967           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1  00000.000000/2020-68                                 Arquivado a pedido
# 2                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3                  None                                          Arquivado
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
# 5  PVL02.003861/2023-24                    Em retificação pelo interessado
# 6  00000.000000/2031-07                                 Arquivado pela STN
# 7                  None  Encaminhado à PGFN com manifestação técnica fa...
# 8                  None                                         Indeferido
# 9                  None                                           Deferido
#
#            num_processo        data_protocolo  \
# 0  19405.000031/2004-78  2004-11-27T02:00:00Z
# 1  17944.001085/2015-81  2015-11-23T02:00:00Z
# 2  19405.000048/2005-14  2005-12-28T02:00:00Z
# 3  19405.000053/2003-57  2003-08-25T03:00:00Z
# 4  17944.000924/2009-03  2010-03-10T03:00:00Z
# 5  17944.001186/2024-42  2024-03-19T14:59:50Z
# 6  17944.000547/2016-23  2016-12-21T02:00:00Z
# 7  19405.000002/2006-78  2009-02-02T02:00:00Z
# 8  19405.000033/2002-03  2002-05-28T03:00:00Z
# 9  17944.000246/2011-95  2011-05-02T03:00:00Z
#
#                                        tipo_operacao  \
# 0  Operação contratual externa (com garantia da U...
# 1  Operação contratual externa (com garantia da U...
# 2  Operação contratual externa (com garantia da U...
# 3  Operação contratual externa (com garantia da U...
# 4  Operação contratual externa (com garantia da U...
# 5                              Concessão de garantia
# 6  Operação contratual interna (com garantia da U...
# 7  Operação contratual externa (com garantia da U...
# 8                        Operação contratual interna
# 9                              Concessão de garantia
#
#                                           finalidade  \
# 0                              Desenvolvimento rural
# 1                                     Multissetorial
# 2                                     Multissetorial
# 3                                     Infraestrutura
# 4                                     Infraestrutura
# 5  Concessão de garantia a empresa estatal não de...
# 6                                 Aditivo contratual
# 7                                     Infraestrutura
# 8                            Renegociação de dívidas
# 9  Concessão de garantia a empresa estatal não de...
#
#                             tipo_credor  \
# 0  Instituição Financeira Internacional
# 1  Instituição Financeira Internacional
# 2  Instituição Financeira Internacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
# 5  Instituição Financeira Internacional
# 6       Instituição Financeira Nacional
# 7  Instituição Financeira Internacional
# 8       Instituição Financeira Nacional
# 9  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 5                               New Development Bank  Dólar dos EUA
# 6                                Banco do Brasil S/A           Real
# 7            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 8  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 9                     Kreditanstalt für Wiederaufbau           Euro
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   35000000.0                 1                      0  09/12/2004
# 1   50000000.0                 0                      0  29/04/2016
# 2  170000000.0                 1                      0  19/04/2006
# 3   35000000.0                 0                      0  20/02/2004
# 4   50000000.0                 1                      0  01/04/2010
# 5  200000000.0                 0                      0  03/04/2024
# 6  698560168.0                 0                      0  16/10/2017
# 7   10000000.0                 1                      0  12/11/2009
# 8   53770000.0                 0                      0  03/07/2002
# 9  100000000.0                 0                      0  19/05/2011

# %%
#verifiquando a quantidade de colunas e linhas do DataFrame:
teste_dados_estado_MG.shape
# Out:
# (41, 18)

# %%
#checando o a frequência de status "Arquivado por decurso de prazo"(possui apenas 1 linha com esse status):
teste_dados_estado_MG['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Em retificação pelo interessado                           1
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
# 3) Qual é o município da Bahia com mais solicitações deferidas?
teste_dados_municipios_BA = consultar_dados_por_uf('BA','Município')
teste_dados_municipios_BA.head(5)
# Out:
#    id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 0      26390        Município               Planaltino   2924900  BA
# 1      32153        Município                    Cairu   2905404  BA
# 2      40753        Município          Rafael Jambeiro   2925956  BA
# 3      42864        Município                   Seabra   2929909  BA
# 4      33908        Município  Muquém de São Francisco   2922250  BA
#
#                 num_pvl             status          num_processo  \
# 0  PVL02.001727/2017-41           Deferido  17944.102293/2017-68
# 1  PVL02.001315/2019-72  Deferido (PVL-IF)                  None
# 2  PVL02.009341/2019-49           Deferido  17944.104612/2019-31
# 3  PVL02.001315/2020-14           Deferido  17944.102889/2020-63
# 4  PVL02.002920/2019-61  Deferido (PVL-IF)                  None
#
#          data_protocolo                tipo_operacao      finalidade  \
# 0  2017-12-11T16:46:43Z  Operação contratual interna  Infraestrutura
# 1                  None  Operação contratual interna  Infraestrutura
# 2  2019-12-04T19:35:20Z  Operação contratual interna  Infraestrutura
# 3  2020-07-14T14:49:00Z  Operação contratual interna  Infraestrutura
# 4                  None  Operação contratual interna  Infraestrutura
#
#                        tipo_credor                                     credor  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 1  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 2  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 3  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 4  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
#
#   moeda      valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  Real  1800000.0                 0                      0  19/12/2017
# 1  Real  4480000.0                 0                      0  22/05/2019
# 2  Real  3000000.0                 0                      0  09/12/2019
# 3  Real  7500000.0                 0                      1  15/07/2020
# 4  Real  1800000.0                 0                      1  01/08/2019

# %%
#Verificação do DataFrame por status no estada da Bahia:

teste_dados_municipios_BA['status'].value_counts()
# Out:
# status
# Deferido                                                 446
# Deferido (PVL-IF)                                        210
# Arquivado por decurso de prazo                           136
# Arquivado                                                108
# Regularizado                                              35
# Encaminhado à PGFN com manifestação técnica favorável     33
# Arquivado a pedido                                        22
# Indeferido                                                10
# Em retificação pelo interessado                            9
# Em retificação pelo credor                                 8
# Pendente de regularização                                  8
# Em retificação pelo credor (PVL-IF)                        2
# Assinado pelo interessado (retificação)                    2
# Em análise                                                 2
# Enviado à instituição financeira (PVL-IF)                  1
# Arquivado a pedido (PVL-IF)                                1
# Indeferido (PVL-IF)                                        1
# Arquivado pela STN                                         1
# Encaminhado à PGFN (decisão judicial)                      1
# Em análise (PVL-IF)                                        1
# Name: count, dtype: int64

# %%
#Verificação da coluna 'status':

municipios_deferido = teste_dados_municipios_BA[teste_dados_municipios_BA['status'] == 'Deferido']
municipios_deferido['status'].value_counts()
# Out:
# status
# Deferido    446
# Name: count, dtype: int64

# %%
#quantidade de municípios com status 'Deferido':
municipios_deferido['interessado'].nunique()
# Out:
# 185

# %%
# 4) Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'.
#Gerando o dataframe:
df_bahia = consultar_dados_por_uf('BA','Estado')
df_bahia.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0       8858           Estado       Bahia        29  BA                  None
# 1      12327           Estado       Bahia        29  BA                  None
# 2      18633           Estado       Bahia        29  BA                  None
# 3      18531           Estado       Bahia        29  BA                  None
# 4      20438           Estado       Bahia        29  BA  00000.000000/2017-83
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000853/2014-06
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001659/2008-91
# 2                                           Deferido  19407.000073/2003-16
# 3                                           Deferido  19407.000044/2002-65
# 4                                           Deferido  17944.001076/2015-90
#
#          data_protocolo                                      tipo_operacao  \
# 0  2014-07-10T03:00:00Z  Operação contratual externa (com garantia da U...
# 1  2009-03-24T03:00:00Z  Operação contratual externa (com garantia da U...
# 2  2004-01-30T02:00:00Z                        Operação contratual interna
# 3  2002-06-11T03:00:00Z                        Operação contratual interna
# 4  2016-03-02T18:35:28Z                        Operação contratual interna
#
#                      finalidade                           tipo_credor  \
# 0                Infraestrutura  Instituição Financeira Internacional
# 1  Fortalecimento Institucional  Instituição Financeira Internacional
# 2             Saneamento básico       Instituição Financeira Nacional
# 3             Saneamento básico       Instituição Financeira Nacional
# 4                Pró-Transporte       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2                            Caixa Econômica Federal           Real
# 3                            Caixa Econômica Federal           Real
# 4                            Caixa Econômica Federal           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  4.000000e+08                 1                      0  16/07/2014
# 1  4.090000e+08                 1                      0  27/03/2009
# 2  2.150132e+08                 1                      0  18/03/2004
# 3  7.360877e+06                 1                      0  05/07/2002
# 4  8.000000e+08                 1                      0  31/03/2016

# %%
#Salvando o arquivo em uma pasta:
df_bahia.to_csv('dataframe_estado_bahia.csv')
